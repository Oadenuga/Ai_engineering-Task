# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


sales= pd.read_csv("sales_data.xls")

# series=
sales.head(20)
# Out:
#                              customer_id  \
# 0   cda7bec0-7cbf-4145-baf9-e049bab94504
# 1   cda7bec0-7cbf-4145-baf9-e049bab94504
# 2   cda7bec0-7cbf-4145-baf9-e049bab94504
# 3   cda7bec0-7cbf-4145-baf9-e049bab94504
# 4   cda7bec0-7cbf-4145-baf9-e049bab94504
# 5   cda7bec0-7cbf-4145-baf9-e049bab94504
# 6   cda7bec0-7cbf-4145-baf9-e049bab94504
# 7   cda7bec0-7cbf-4145-baf9-e049bab94504
# 8   cda7bec0-7cbf-4145-baf9-e049bab94504
# 9   cda7bec0-7cbf-4145-baf9-e049bab94504
# 10  cda7bec0-7cbf-4145-baf9-e049bab94504
# 11  cda7bec0-7cbf-4145-baf9-e049bab94504
# 12  cda7bec0-7cbf-4145-baf9-e049bab94504
# 13  cda7bec0-7cbf-4145-baf9-e049bab94504
# 14  cda7bec0-7cbf-4145-baf9-e049bab94504
# 15  cda7bec0-7cbf-4145-baf9-e049bab94504
# 16  cda7bec0-7cbf-4145-baf9-e049bab94504
# 17  cda7bec0-7cbf-4145-baf9-e049bab94504
# 18  cda7bec0-7cbf-4145-baf9-e049bab94504
# 19  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                device_id  item_id  line_item_id  \
# ...

# %%
sales.isna().sum()
# Out:
# customer_id        0
# device_id          0
# item_id            0
# line_item_id       0
# order_id           0
# event_id           0
# event_timestamp    0
# quantity           0
# currency           0
# checked_out_at     0
# status             0
# location           0
# dtype: int64

# %%
sales.columns
# Out:
# Index(['customer_id', 'device_id', 'item_id', 'line_item_id', 'order_id',
#        'event_id', 'event_timestamp', 'quantity', 'currency', 'checked_out_at',
#        'status', 'location'],
#       dtype='object')

# %%
import pandas as pd

sales= pd.read_csv("sales_data.xls")

sales.loc[[0,2,4,6],['customer_id','device_id','item_id']]
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 6  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id
# 0        4
# 2        9
# 4        6
# 6        4

# %%
sales.iloc[[0,1,2,3], [0,1,2,3,5]]
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 1  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 3  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id  event_id
# 0        4          3201     14786
# 1        5          3202     14786
# 2        9          3203     14786
# 3       12          3204     14786

# %%
sales.loc[0:10, 'customer_id': 'status']
# Out:
#                              customer_id  \
# 0   cda7bec0-7cbf-4145-baf9-e049bab94504
# 1   cda7bec0-7cbf-4145-baf9-e049bab94504
# 2   cda7bec0-7cbf-4145-baf9-e049bab94504
# 3   cda7bec0-7cbf-4145-baf9-e049bab94504
# 4   cda7bec0-7cbf-4145-baf9-e049bab94504
# 5   cda7bec0-7cbf-4145-baf9-e049bab94504
# 6   cda7bec0-7cbf-4145-baf9-e049bab94504
# 7   cda7bec0-7cbf-4145-baf9-e049bab94504
# 8   cda7bec0-7cbf-4145-baf9-e049bab94504
# 9   cda7bec0-7cbf-4145-baf9-e049bab94504
# 10  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                device_id  item_id  line_item_id  \
# 0   33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 1   33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# 2   33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 3   33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# 4   33b485de-7338-4997-b1d0-b988ba17b245        6          3205
# 5   33b485de-7338-4997-b1d0-b988ba17b245       11          3206
# ...

# %%
sales.set_index("location", inplace= True)

# %%
sales.index.value_counts().head(20).plot(kind= 'bar')
# Out:
# <Axes: xlabel='location'>

# %%
Kora=sales.loc["Korea"]
Kora
# Out:
#                                    customer_id  \
# location
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# ...                                        ...
# Korea     e9345bdc-3b15-4cab-9526-0d690021db61
# Korea     e9345bdc-3b15-4cab-9526-0d690021db61
# Korea     e9345bdc-3b15-4cab-9526-0d690021db61
# Korea     e9345bdc-3b15-4cab-9526-0d690021db61
# Korea     e9345bdc-3b15-4cab-9526-0d690021db61
#
#                                      device_id  item_id  line_item_id  \
# location
# Korea     01cf516e-66e6-45f2-a6d6-b6f5f5232778       14          3914
# Korea     01cf516e-66e6-45f2-a6d6-b6f5f5232778        8          3915
# Korea     01cf516e-66e6-45f2-a6d6-b6f5f5232778       10          3916
# Korea     01cf516e-66e6-45f2-a6d6-b6f5f5232778        4          3917
# ...

# %%
Kora.value_counts()
# Out:
# customer_id                           device_id                             item_id  line_item_id  order_id                              event_id  event_timestamp             quantity  currency  checked_out_at              status
# 06a20369-6680-4f64-874e-c304b6b5b9c9  2b2e9c57-57ba-4be5-8596-90e2d797f21c  1        18774         8d1ab0f5-0677-44c7-988a-9ca5bb90a16c  87008     2024-03-23 05:02:30.672670  5         USD       2024-03-30 04:07:14.259777  cancelled    1
#                                                                                                                                          87009     2024-03-22 01:31:03.161120  5         USD       2024-03-30 04:07:14.259777  cancelled    1
#                                                                                                                                          87010     2024-03-24 14:59:18.291295  5         USD       2024-03-30 04:07:14.259777  cancelled    1
# ...

# %%
sales.loc["Korea"].nunique().value_counts()
# Out:
# 46     4
# 3      2
# 15     1
# 347    1
# 809    1
# 777    1
# 5      1
# Name: count, dtype: int64

# %%
sales["customer_id"].value_counts().sort_values(ascending=False).head(20)
# Out:
# customer_id
# eb7dcb88-073d-403e-bdd4-1e5725fe2338    372
# a7d9058a-163e-4632-9bde-1f57130130cb    360
# 12e94262-2eaa-47d9-85c9-6f55e434f5c8    360
# ebcea232-0615-44be-8f9e-338100c6b31c    360
# ebcb2343-be1b-421e-83eb-6f79a321d999    360
# be8ce4e3-c596-43c2-8b70-bdcecada2139    360
# e4431b51-8db8-4b4a-a871-d12e3eaca47d    360
# c391f179-9eb3-418d-9d7b-b261f2dc57a6    360
# 9ff854ce-3c64-4519-8bc8-4f33713a1457    348
# a68a4174-0109-4469-ab21-d49b48750829    348
# e73af64f-4c71-417a-94cc-7e0f2379cd3e    348
# d3cd2a61-03cf-4749-b693-5e5dc4f32b9c    348
# 82e02b41-5f63-429f-8e92-1787d86a0b66    348
# 2625fe82-4acd-4c33-a262-e437cd52e698    348
# 23ea9949-0d0f-403f-a141-e8446ce341e2    348
# 64a744f1-f229-4c75-b623-347558d684d9    348
# 5d4624cc-7372-4003-bd9d-9a53704650a1    348
# 12b8be6b-be79-4cc2-9666-04852788ab4a    348
# 25ca6238-bc27-453a-b5e3-0a478f3f4e22    348
# abc8403d-526f-443f-8403-cc1402500ac7    348
# Name: count, dtype: int64

# %%
sales["customer_id"].nunique()
# Out:
# 4594

# %%
msak=[sales["event_id"]== "121373"]
msak
# Out:
# [location
#  Saint Helena        False
#  Saint Helena        False
#  Saint Helena        False
#  Saint Helena        False
#  Saint Helena        False
#                      ...
#  Christmas Island    False
#  Christmas Island    False
#  Christmas Island    False
#  Christmas Island    False
#  Christmas Island    False
#  Name: event_id, Length: 578320, dtype: bool]

# %%
sales["currency"].unique()
# Out:
# array(['NGN', 'USD', 'GBP'], dtype=object)

# %%
sales["currency"].nunique()
# Out:
# 3

# %%
sales["device_id"].nunique()
# Out:
# 4594

# %%
sales["device_id"].unique()
# Out:
# array(['33b485de-7338-4997-b1d0-b988ba17b245',
#        '428688d6-31e6-4c73-a5d0-c8e849ccf6a3',
#        'eab9f1d1-c830-44ed-a34f-d65ac40c54dc', ...,
#        '12b1e800-e585-4de6-a63f-22ad8adb4354',
#        '35a035eb-5b04-45ff-8be7-66b8bbcc20a4',
#        '74bb4936-9890-421b-a62a-ee544191fa1e'],
#       shape=(4594,), dtype=object)

# %%
devi=sales[sales["device_id"]== "33b485de-7338-4997-b1d0-b988ba17b245"].head(10)
devi
# Out:
#                                        customer_id  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# ...

# %%
devi.nunique()  #one  device used same customer id
# Out:
# customer_id        1
# device_id          1
# item_id            6
# line_item_id       6
# order_id           1
# event_id           2
# event_timestamp    2
# quantity           4
# currency           1
# checked_out_at     1
# status             1
# dtype: int64

# %%
devi.loc['Saint Helena': 'customer_id' 'order_id' 'event_id']
# Out:
#                                        customer_id  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# ...

# %%
devi.loc['Saint Helena': 'customer_id' 'order_id' 'event_id'].nunique()
# Out:
# customer_id        1
# device_id          1
# item_id            6
# line_item_id       6
# order_id           1
# event_id           2
# event_timestamp    2
# quantity           4
# currency           1
# checked_out_at     1
# status             1
# dtype: int64

# %%
sales["location"].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Adenuga Pelumi\Documents\Complete AI course\week_5\module_new\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ...

# %%
testing=sales[sales["device_id"]== "33b485de-7338-4997-b1d0-b988ba17b245"].head(10)
testing
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 1  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 3  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 5  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 6  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 7  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 8  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 9  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id                              order_id  event_id  \
# ...

# %%
checkin_coast=sales[sales["location"] == "Costa Rica"]
checkin_coast
# Out:
#                                  customer_id  \
# 5503    40375178-0921-4a22-9f18-2d09fc3b5ff7
# 5504    40375178-0921-4a22-9f18-2d09fc3b5ff7
# 5505    40375178-0921-4a22-9f18-2d09fc3b5ff7
# 5506    40375178-0921-4a22-9f18-2d09fc3b5ff7
# 5507    40375178-0921-4a22-9f18-2d09fc3b5ff7
# ...                                      ...
# 564819  7517bdaf-1527-4d03-acc1-d719142bce64
# 564820  7517bdaf-1527-4d03-acc1-d719142bce64
# 564821  7517bdaf-1527-4d03-acc1-d719142bce64
# 564822  7517bdaf-1527-4d03-acc1-d719142bce64
# 564823  7517bdaf-1527-4d03-acc1-d719142bce64
#
#                                    device_id  item_id  line_item_id  \
# 5503    718f3de5-36d3-4b4e-9402-15152b346ae3        2          3497
# 5504    718f3de5-36d3-4b4e-9402-15152b346ae3        7          3498
# 5505    718f3de5-36d3-4b4e-9402-15152b346ae3       12          3499
# 5506    718f3de5-36d3-4b4e-9402-15152b346ae3        5          3500
# 5507    718f3de5-36d3-4b4e-9402-15152b346ae3       14          3501
# ...

# %%
checkin_coast_status=checkin_coast[sales["status"]== "success"]
checkin_coast_status.shape
# Out:
# C:\Users\Adenuga Pelumi\AppData\Local\Temp\ipykernel_35160\885309631.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   checkin_coast_status=checkin_coast[sales["status"]== "success"]
# (240, 12)

# %%
checkin_coast["status"].value_counts()
# Out:
# status
# cancelled    1365
# failed        606
# success       240
# Name: count, dtype: int64

# %%
graph_coast=sales["status"].value_counts().plot(kind= 'bar')
graph_coast
# Out:
# <Axes: xlabel='status'>

# %%
Nigeria_checking=sales[sales["location"]== "Nigeria"]
Nigeria_checking.shape
# Out:
# (2036, 12)

# %%
Nigeria_checking["status"].value_counts()
# Out:
# status
# success      758
# failed       662
# cancelled    616
# Name: count, dtype: int64

# %%
customer= Nigeria_checking["customer_id"]
customer.value_counts()
# Out:
# customer_id
# e5b13bcf-8f44-47c6-a765-433a507b7688    242
# cbc2f7f8-37a3-41c2-8ed5-f4243b87d0ca    220
# d1462fe7-99f6-41fa-85cd-a7dd725aa522    220
# ca28be50-11a8-4fd1-8ada-6f5dfd471972    171
# 82d88879-7ea2-41da-87c2-695c41c029d3    160
# 49ab79cb-cd87-41b5-803f-798a0a98cce3    144
# 7edb231c-8c49-4b2f-a4cb-71b642dd0142    144
# 47da92d6-515c-4ecc-889d-5bcf1d855026    136
# 397af862-e7bb-412f-864d-421d08a805bf    128
# 8aabfc1a-4395-4e8b-82b4-6e8cc2b07586    105
# 711263f6-1007-4c41-a7c3-ab765d752ca4    102
# 60b209f9-877d-4d74-87d1-0eba26eb75ae     84
# 836a3918-bf3f-4aa4-84d0-1e362077cf91     72
# cef67eaf-88f4-4fe8-b37a-376f3fbaa090     60
# 9e816ede-f454-461c-b318-048ce8cdf28c     24
# 24377f83-447b-4bb2-8a49-d38d047fa104     12
# 916401c0-8d4c-40b3-91d3-2adf0d6d814f      8
# bfc54ca0-1721-468e-be70-c954797e89b0      4
# Name: count, dtype: int64

# %%
customer.value_counts()
# Out:
# customer_id
# e5b13bcf-8f44-47c6-a765-433a507b7688    242
# cbc2f7f8-37a3-41c2-8ed5-f4243b87d0ca    220
# d1462fe7-99f6-41fa-85cd-a7dd725aa522    220
# ca28be50-11a8-4fd1-8ada-6f5dfd471972    171
# 82d88879-7ea2-41da-87c2-695c41c029d3    160
# 49ab79cb-cd87-41b5-803f-798a0a98cce3    144
# 7edb231c-8c49-4b2f-a4cb-71b642dd0142    144
# 47da92d6-515c-4ecc-889d-5bcf1d855026    136
# 397af862-e7bb-412f-864d-421d08a805bf    128
# 8aabfc1a-4395-4e8b-82b4-6e8cc2b07586    105
# 711263f6-1007-4c41-a7c3-ab765d752ca4    102
# 60b209f9-877d-4d74-87d1-0eba26eb75ae     84
# 836a3918-bf3f-4aa4-84d0-1e362077cf91     72
# cef67eaf-88f4-4fe8-b37a-376f3fbaa090     60
# 9e816ede-f454-461c-b318-048ce8cdf28c     24
# 24377f83-447b-4bb2-8a49-d38d047fa104     12
# 916401c0-8d4c-40b3-91d3-2adf0d6d814f      8
# bfc54ca0-1721-468e-be70-c954797e89b0      4
# Name: count, dtype: int64

# %%
customer
# Out:
# 75037     916401c0-8d4c-40b3-91d3-2adf0d6d814f
# 75038     916401c0-8d4c-40b3-91d3-2adf0d6d814f
# 75039     916401c0-8d4c-40b3-91d3-2adf0d6d814f
# 75040     916401c0-8d4c-40b3-91d3-2adf0d6d814f
# 75041     916401c0-8d4c-40b3-91d3-2adf0d6d814f
#                           ...
# 537954    8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# 537955    8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# 537956    8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# 537957    8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# 537958    8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Name: customer_id, Length: 2036, dtype: object

# %%
cus_inspec= (sales["customer_id"]== "e5b13bcf-8f44-47c6-a765-433a507b7688 " ) & (sales["status"]== "sucess")

# %%
this=sales.loc[cus_inspec]

# %%
this["status"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
mask3=(sales["status"]==  "failed")
mask3
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 578315     True
# 578316     True
# 578317     True
# 578318     True
# 578319     True
# Name: status, Length: 578320, dtype: bool

# %%
mas3= sales[sales["status"]== "failed"]
mas3
# Out:
#                                            customer_id  \
# location
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Mali              f40fc2b7-0a0f-46e8-8fc5-4edfa5eb832b
# ...                                                ...
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                              device_id  item_id  line_item_id  \
# location
# Djibouti          428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Djibouti          428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# ...

# %%
sales.loc[mask3]
# Out:
#                                  customer_id  \
# 84      e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# 85      e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# 86      e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# 87      e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# 214     f40fc2b7-0a0f-46e8-8fc5-4edfa5eb832b
# ...                                      ...
# 578315  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578316  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578318  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578319  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id  \
# 84      428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# 85      428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# 86      428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# 87      428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# 214     76c265ff-c670-433a-887f-4b0d7a991349        4          3215
# ...

# %%
Korea = sales.loc["Korea"]
Korea.head(2)
# Out:
#                                    customer_id  \
# location
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
#
#                                      device_id  item_id  line_item_id  \
# location
# Korea     01cf516e-66e6-45f2-a6d6-b6f5f5232778       14          3914
# Korea     01cf516e-66e6-45f2-a6d6-b6f5f5232778        8          3915
#
#                                       order_id  event_id  \
# location
# Korea     b253052f-6f62-4b1f-bce2-ab2324a2a27c     18219
# Korea     b253052f-6f62-4b1f-bce2-ab2324a2a27c     18219
#
#                      event_timestamp  quantity currency  \
# location
# Korea     2024-03-19 10:01:39.523573         5      USD
# Korea     2024-03-19 10:01:39.523573         2      USD
#
#                       checked_out_at     status
# location
# Korea     2024-03-30 04:06:10.636247  cancelled
# Korea     2024-03-30 04:06:10.636247  cancelled

# %%
sales.head()
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 1  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 3  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id                              order_id  event_id  \
# 0        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 1        5          3202  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 2        9          3203  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 3       12          3204  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 4        6          3205  9e950ce3-2e12-479c-a051-493c1a497d49     14786
#
# ...

# %%
sales.set_index("location", inplace=True)

# %%
sales.loc["Korea"]
# Out:
#                                    customer_id  \
# location
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# ...                                        ...
# Korea     e9345bdc-3b15-4cab-9526-0d690021db61
# Korea     e9345bdc-3b15-4cab-9526-0d690021db61
# Korea     e9345bdc-3b15-4cab-9526-0d690021db61
# Korea     e9345bdc-3b15-4cab-9526-0d690021db61
# Korea     e9345bdc-3b15-4cab-9526-0d690021db61
#
#                                      device_id  item_id  line_item_id  \
# location
# Korea     01cf516e-66e6-45f2-a6d6-b6f5f5232778       14          3914
# Korea     01cf516e-66e6-45f2-a6d6-b6f5f5232778        8          3915
# Korea     01cf516e-66e6-45f2-a6d6-b6f5f5232778       10          3916
# Korea     01cf516e-66e6-45f2-a6d6-b6f5f5232778        4          3917
# ...

# %%
saint = sales[sales["customer_id"] =="3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9"]
saint
# Out:
#                                    customer_id  \
# location
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# ...                                        ...
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
# Korea     3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9
#
#                                      device_id  item_id  line_item_id  \
# location
# Korea     01cf516e-66e6-45f2-a6d6-b6f5f5232778       14          3914
# Korea     01cf516e-66e6-45f2-a6d6-b6f5f5232778        8          3915
# Korea     01cf516e-66e6-45f2-a6d6-b6f5f5232778       10          3916
# Korea     01cf516e-66e6-45f2-a6d6-b6f5f5232778        4          3917
# ...

# %%
check_saint= saint["status"]== "sucess"
check_saint.head()
# Out:
# location
# Korea    False
# Korea    False
# Korea    False
# Korea    False
# Korea    False
# Name: status, dtype: bool

# %%
check_sai= saint["status"].value_counts().plot(kind= "bar")

# %%
sales.head(800)
# Out:
#                                        customer_id  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                            ...
# Sudan         b7b16a2a-b32e-4486-a782-66dbbb3106ea
# Sudan         b7b16a2a-b32e-4486-a782-66dbbb3106ea
# Sudan         b7b16a2a-b32e-4486-a782-66dbbb3106ea
# Sudan         b7b16a2a-b32e-4486-a782-66dbbb3106ea
# Sudan         b7b16a2a-b32e-4486-a782-66dbbb3106ea
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# ...

# %%
locate_sudan= sales.loc["Sudan"]
locate_sudan
# Out:
#                                    customer_id  \
# location
# Sudan     b7b16a2a-b32e-4486-a782-66dbbb3106ea
# Sudan     b7b16a2a-b32e-4486-a782-66dbbb3106ea
# Sudan     b7b16a2a-b32e-4486-a782-66dbbb3106ea
# Sudan     b7b16a2a-b32e-4486-a782-66dbbb3106ea
# Sudan     b7b16a2a-b32e-4486-a782-66dbbb3106ea
# ...                                        ...
# Sudan     bedd2b9f-9639-4de3-bb20-2ef4f1b087fc
# Sudan     bedd2b9f-9639-4de3-bb20-2ef4f1b087fc
# Sudan     bedd2b9f-9639-4de3-bb20-2ef4f1b087fc
# Sudan     bedd2b9f-9639-4de3-bb20-2ef4f1b087fc
# Sudan     bedd2b9f-9639-4de3-bb20-2ef4f1b087fc
#
#                                      device_id  item_id  line_item_id  \
# location
# Sudan     004c6716-21c7-4c52-871f-010dce4f7ffc        1          3251
# Sudan     004c6716-21c7-4c52-871f-010dce4f7ffc        9          3252
# Sudan     004c6716-21c7-4c52-871f-010dce4f7ffc       11          3253
# Sudan     004c6716-21c7-4c52-871f-010dce4f7ffc        1          3251
# ...

# %%
transaction_sudan= locate_sudan["status"].value_counts()
transaction_sudan
# Out:
# status
# cancelled    1086
# failed        360
# success       216
# Name: count, dtype: int64

# %%
transaction_sudan.plot(kind= "bar")
# Out:
# <Axes: xlabel='status'>

# %%
currency= locate_sudan["currency"]
currency.unique()
# Out:
# array(['USD', 'NGN', 'GBP'], dtype=object)

# %%
failed= locate_sudan[locate_sudan["status"] == "failed"]
failed.value_counts()
# Out:
# customer_id                           device_id                             item_id  line_item_id  order_id                              event_id  event_timestamp             quantity  currency  checked_out_at              status
# 26ed9e62-a5c5-4f1e-97b4-e962af8006e0  acc3b4f4-c23a-4a81-9f02-214b84e6cdc5  1        28207         c3386edc-900d-41fa-ad07-83c161883520  130915    2024-03-30 04:03:16.542266  1         GBP       2024-03-30 04:10:16.542328  failed    1
#                                                                                                                                          130916    2024-03-30 04:03:16.542267  1         GBP       2024-03-30 04:10:16.542328  failed    1
#                                                                                                                                          130917    2024-03-30 04:03:16.542313  1         GBP       2024-03-30 04:10:16.542328  failed    1
# ...

# %%
faile= locate_sudan["status"]
faile.value_counts()
# Out:
# status
# cancelled    1086
# failed        360
# success       216
# Name: count, dtype: int64

# %%
failed_test= locate_sudan["status"] == "failed"
failed_test.value_counts()
# Out:
# status
# False    1302
# True      360
# Name: count, dtype: int64

# %%
failed_test.head()
# Out:
# location
# Sudan    False
# Sudan    False
# Sudan    False
# Sudan    False
# Sudan    False
# Name: status, dtype: bool

# %%
Nigeria_checking= sales.loc["Nigeria"]
Nigeria_checking
# Out:
#                                    customer_id  \
# location
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# ...                                        ...
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
#
#                                      device_id  item_id  line_item_id  \
# location
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# ...

# %%
Nigeria_checking.tail(10)
# Out:
#                                    customer_id  \
# location
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
#
#                                      device_id  item_id  line_item_id  \
# location
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23        4         32698
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23       12         32699
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23       14         32700
# Nigeria   5843c4cf-75c8-4f99-a6ec-e0392cd5bb23        8         32694
# ...

# %%
Nigeria_checking.describe()
# Out:
#            item_id  line_item_id       event_id     quantity
# count  2036.000000   2036.000000    2036.000000  2036.000000
# mean      7.767682  19689.939096   91350.221022     2.957269
# std       4.292563   7972.475027   37057.528067     1.359159
# min       1.000000   7316.000000   33989.000000     1.000000
# 25%       4.000000  13477.000000   62554.000000     2.000000
# 50%       8.000000  16184.000000   75440.000000     3.000000
# 75%      11.000000  25681.000000  119514.000000     4.000000
# max      15.000000  32700.000000  151799.000000     5.000000

# %%
Nigeria_checking.isna().sum()
# Out:
# customer_id        0
# device_id          0
# item_id            0
# line_item_id       0
# order_id           0
# event_id           0
# event_timestamp    0
# quantity           0
# currency           0
# checked_out_at     0
# status             0
# dtype: int64

# %%
Nigeria_checking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2036 entries, Nigeria to Nigeria
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      2036 non-null   object
#  1   device_id        2036 non-null   object
#  2   item_id          2036 non-null   int64
#  3   line_item_id     2036 non-null   int64
#  4   order_id         2036 non-null   object
#  5   event_id         2036 non-null   int64
#  6   event_timestamp  2036 non-null   object
#  7   quantity         2036 non-null   int64
#  8   currency         2036 non-null   object
#  9   checked_out_at   2036 non-null   object
#  10  status           2036 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 255.4+ KB

# %%
Nigeria_checking.shape
# Out:
# (2036, 11)

# %%
Nigeria_checking["status"].value_counts()
# Out:
# status
# success      758
# failed       662
# cancelled    616
# Name: count, dtype: int64

# %%
Nigeria_checking["status"].value_counts().plot(kind= "bar")
# Out:
# <Axes: xlabel='status'>

# %%
Niger_map=Nigeria_checking["status"].value_counts()
Niger_map.plot(kind= "bar")
# Out:
# <Axes: xlabel='status'>

# %%
succes_Niger= Nigeria_checking[Nigeria_checking["status"]=="success"]
failed_Niger= Nigeria_checking[Nigeria_checking["status"]=="failed"]
cancelled_Niger= Nigeria_checking[Nigeria_checking["status"]=="cancelled"]

# %%
succes_Niger.head()
# Out:
#                                    customer_id  \
# location
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
#
#                                      device_id  item_id  line_item_id  \
# location
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
#
#                                       order_id  event_id  \
# location
# Nigeria   b760345e-68d8-47e7-86db-23787c55056f     33989
# Nigeria   b760345e-68d8-47e7-86db-23787c55056f     33989
# ...

# %%
succes_Niger.customer_id.value_counts()
# Out:
# customer_id
# ca28be50-11a8-4fd1-8ada-6f5dfd471972    171
# 7edb231c-8c49-4b2f-a4cb-71b642dd0142    144
# 49ab79cb-cd87-41b5-803f-798a0a98cce3    144
# 8aabfc1a-4395-4e8b-82b4-6e8cc2b07586    105
# 711263f6-1007-4c41-a7c3-ab765d752ca4    102
# 60b209f9-877d-4d74-87d1-0eba26eb75ae     84
# 916401c0-8d4c-40b3-91d3-2adf0d6d814f      8
# Name: count, dtype: int64

# %%
succes_Niger.customer_id.unique()
# Out:
# array(['916401c0-8d4c-40b3-91d3-2adf0d6d814f',
#        '49ab79cb-cd87-41b5-803f-798a0a98cce3',
#        '7edb231c-8c49-4b2f-a4cb-71b642dd0142',
#        '60b209f9-877d-4d74-87d1-0eba26eb75ae',
#        'ca28be50-11a8-4fd1-8ada-6f5dfd471972',
#        '711263f6-1007-4c41-a7c3-ab765d752ca4',
#        '8aabfc1a-4395-4e8b-82b4-6e8cc2b07586'], dtype=object)

# %%
sales.head()
# Out:
#                             customer_id                             device_id  \
# 0  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 1  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 3  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id                              order_id  event_id  \
# 0        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 1        5          3202  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 2        9          3203  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 3       12          3204  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 4        6          3205  9e950ce3-2e12-479c-a051-493c1a497d49     14786
#
# ...

# %%
succes_Niger.shape[0]
# Out:
# 758

# %%
testing_both=  sales[(sales["location"]=='Nigeria') & (sales["status"]== "success")]
testing_both.nunique()
# Out:
# customer_id          7
# device_id            7
# item_id             15
# line_item_id        46
# order_id             7
# event_id           105
# event_timestamp    104
# quantity             5
# currency             2
# checked_out_at       7
# status               1
# location             1
# dtype: int64

# %%
testing_both.count()
# Out:
# customer_id        758
# device_id          758
# item_id            758
# line_item_id       758
# order_id           758
# event_id           758
# event_timestamp    758
# quantity           758
# currency           758
# checked_out_at     758
# status             758
# location           758
# dtype: int64

# %%
sales.loc['Nigeria']
# Out:
#                                    customer_id  \
# location
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# ...                                        ...
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
# Nigeria   8aabfc1a-4395-4e8b-82b4-6e8cc2b07586
#
#                                      device_id  item_id  line_item_id  \
# location
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef       13          7316
# Nigeria   938a10df-513f-49f9-99a6-668c96b503ef        6          7317
# ...

# %%
Nigeria_checking.head(50)
# Out:
#                                    customer_id  \
# location
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   916401c0-8d4c-40b3-91d3-2adf0d6d814f
# Nigeria   cbc2f7f8-37a3-41c2-8ed5-f4243b87d0ca
# Nigeria   cbc2f7f8-37a3-41c2-8ed5-f4243b87d0ca
# Nigeria   cbc2f7f8-37a3-41c2-8ed5-f4243b87d0ca
# Nigeria   cbc2f7f8-37a3-41c2-8ed5-f4243b87d0ca
# Nigeria   cbc2f7f8-37a3-41c2-8ed5-f4243b87d0ca
# Nigeria   cbc2f7f8-37a3-41c2-8ed5-f4243b87d0ca
# Nigeria   cbc2f7f8-37a3-41c2-8ed5-f4243b87d0ca
# Nigeria   cbc2f7f8-37a3-41c2-8ed5-f4243b87d0ca
# Nigeria   cbc2f7f8-37a3-41c2-8ed5-f4243b87d0ca
# Nigeria   cbc2f7f8-37a3-41c2-8ed5-f4243b87d0ca
# Nigeria   cbc2f7f8-37a3-41c2-8ed5-f4243b87d0ca
# ...

# %%
sucess= Nigeria_checking[Nigeria_checking["status"]== 'cancelled']
sucess.head(2)
# Out:
#                                    customer_id  \
# location
# Nigeria   cbc2f7f8-37a3-41c2-8ed5-f4243b87d0ca
# Nigeria   cbc2f7f8-37a3-41c2-8ed5-f4243b87d0ca
#
#                                      device_id  item_id  line_item_id  \
# location
# Nigeria   2564296b-c6c0-4855-877c-efce9a2f5d7c       10          9774
# Nigeria   2564296b-c6c0-4855-877c-efce9a2f5d7c       15          9775
#
#                                       order_id  event_id  \
# location
# Nigeria   b68a7630-76e2-4b26-bb4d-d4d1afcc6f84     45092
# Nigeria   b68a7630-76e2-4b26-bb4d-d4d1afcc6f84     45092
#
#                      event_timestamp  quantity currency  \
# location
# Nigeria   2024-03-26 07:29:14.916708         1      USD
# Nigeria   2024-03-26 07:29:14.916708         2      USD
#
#                       checked_out_at     status
# location
# Nigeria   2024-03-30 04:17:12.065727  cancelled
# Nigeria   2024-03-30 04:17:12.065727  cancelled

# %%
Nigeria_checking.shape[0]
# Out:
# 2036

# %%
Nigeria_checking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2036 entries, Nigeria to Nigeria
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      2036 non-null   object
#  1   device_id        2036 non-null   object
#  2   item_id          2036 non-null   int64
#  3   line_item_id     2036 non-null   int64
#  4   order_id         2036 non-null   object
#  5   event_id         2036 non-null   int64
#  6   event_timestamp  2036 non-null   object
#  7   quantity         2036 non-null   int64
#  8   currency         2036 non-null   object
#  9   checked_out_at   2036 non-null   object
#  10  status           2036 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 255.4+ KB

# %%
failed_cancelled= Nigeria_checking[Nigeria_checking["status"]== 'failed']
failed_cancelled.head(30)
# Out:
#                                    customer_id  \
# location
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# Nigeria   d1462fe7-99f6-41fa-85cd-a7dd725aa522
# ...

# %%
new_cuz= sucess[sucess["customer_id"]=="916401c0-8d4c-40b3-91d3-2adf0d6d814f"]
# Out:
# Empty DataFrame
# Columns: [customer_id, device_id, item_id, line_item_id, order_id, event_id, event_timestamp, quantity, currency, checked_out_at, status]
# Index: []

# %%
sales["device_id"].nunique()
# Out:
# 4594

# %%
sales["item_id"].value_counts()
# Out:
# item_id
# 11    39715
# 15    39268
# 8     39162
# 10    39084
# 2     38997
# 1     38866
# 4     38842
# 6     38835
# 5     38782
# 12    38440
# 7     38291
# 14    38043
# 13    37515
# 3     37501
# 9     36979
# Name: count, dtype: int64

# %%
sales["item_id"].unique()
# Out:
# array([ 4,  5,  9, 12,  6, 11, 13, 15,  8,  1, 10,  2, 14,  7,  3])

# %%
mask4= (sales["status"].str.contains("failed"))
mask4.shape
# Out:
# (578320,)

# %%
sales.loc[mask4].head(4)
# Out:
#                                    customer_id  \
# location
# Djibouti  e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti  e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti  e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti  e7f07fd1-05af-494a-ae5a-78c405b6f9c3
#
#                                      device_id  item_id  line_item_id  \
# location
# Djibouti  428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Djibouti  428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Djibouti  428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Djibouti  428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
#
#                                       order_id  event_id  \
# location
# Djibouti  cddddfea-27ef-437f-817d-8f849d604c3c     14800
# Djibouti  cddddfea-27ef-437f-817d-8f849d604c3c     14801
# Djibouti  cddddfea-27ef-437f-817d-8f849d604c3c     14802
# Djibouti  cddddfea-27ef-437f-817d-8f849d604c3c     14803
#
# ...

# %%
sales.loc[~mask4].head(10)
# Out:
#                                        customer_id  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# ...

# %%
sales.columns
# Out:
# Index(['customer_id', 'device_id', 'item_id', 'line_item_id', 'order_id',
#        'event_id', 'event_timestamp', 'quantity', 'currency', 'checked_out_at',
#        'status'],
#       dtype='object')

# %%
df2=sales.copy()

# %%
df2.head(2)
# Out:
#                                        customer_id  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
#
#                                           order_id  event_id  \
# location
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
#
#                          event_timestamp  quantity currency  \
# location
# Saint Helena  2024-03-26 22:05:58.863661         2      NGN
# Saint Helena  2024-03-26 22:05:58.863661         4      NGN
#
#                           checked_out_at   status
# location
# Saint Helena  2024-03-30 04:19:10.406794  success
# Saint Helena  2024-03-30 04:19:10.406794  success

# %%
df2.rename(columns= {"customer_id":"customer_ID"}, inplace=True)

# %%
df2.head(2)
# Out:
#                                        customer_ID  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
#
#                                           order_id  event_id  \
# location
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
#
#                          event_timestamp  quantity currency  \
# location
# Saint Helena  2024-03-26 22:05:58.863661         2      NGN
# Saint Helena  2024-03-26 22:05:58.863661         4      NGN
#
#                           checked_out_at   status
# location
# Saint Helena  2024-03-30 04:19:10.406794  success
# Saint Helena  2024-03-30 04:19:10.406794  success

# %%
df2.rename(columns = {"device_id":"DEVICE_ID"},inplace = True)

# %%
df2.columns= df2.columns.str.upper()

# %%
df2.head(1)
# Out:
#                                        CUSTOMER_ID  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          DEVICE_ID  ITEM_ID  LINE_ITEM_ID  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
#
#                                           ORDER_ID  EVENT_ID  \
# location
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
#
#                          EVENT_TIMESTAMP  QUANTITY CURRENCY  \
# location
# Saint Helena  2024-03-26 22:05:58.863661         2      NGN
#
#                           CHECKED_OUT_AT   STATUS
# location
# Saint Helena  2024-03-30 04:19:10.406794  success

# %%
df2.columns= [x.upper() for x in df2.columns]

# %%
df2.columns
# Out:
# Index(['CUSTOMER_ID', 'DEVICE_ID', 'ITEM_ID', 'LINE_ITEM_ID', 'ORDER_ID',
#        'EVENT_ID', 'EVENT_TIMESTAMP', 'QUANTITY', 'CURRENCY', 'CHECKED_OUT_AT',
#        'STATUS'],
#       dtype='object')

# %%
df2.columns= [x.lower() for x in df2.columns]

# %%
df2.columns
# Out:
# Index(['customer_ID', 'DEVICE_ID', 'item_id', 'line_item_id', 'order_id',
#        'event_id', 'event_timestamp', 'quantity', 'currency', 'checked_out_at',
#        'status'],
#       dtype='object')

# %%
df2.apply(len)
# Out:
# customer_ID        578320
# DEVICE_ID          578320
# item_id            578320
# line_item_id       578320
# order_id           578320
# event_id           578320
# event_timestamp    578320
# quantity           578320
# currency           578320
# checked_out_at     578320
# status             578320
# dtype: int64

# %%
df2.apply(lambda x: x.min())
# Out:
# customer_ID        00096d0c-ced3-4913-afe9-5ce363f7126f
# DEVICE_ID          000f53e2-b76e-4d2e-9db1-123c9535b5dc
# item_id                                               1
# line_item_id                                       3201
# order_id           0013dca7-52fe-4794-ad3b-7b30958b368f
# event_id                                          14786
# event_timestamp              2024-03-19 04:06:12.469246
# quantity                                              1
# currency                                            GBP
# checked_out_at               2024-03-30 04:06:10.418189
# status                                        cancelled
# dtype: object

# %%
df2["customer_ID"].apply(len)
# Out:
# location
# Saint Helena        36
# Saint Helena        36
# Saint Helena        36
# Saint Helena        36
# Saint Helena        36
#                     ..
# Christmas Island    36
# Christmas Island    36
# Christmas Island    36
# Christmas Island    36
# Christmas Island    36
# Name: customer_ID, Length: 578320, dtype: int64

# %%
def capital_cas(x):
    return x.upper()

# %%
df2["status"].apply(capital_cas)
# Out:
# location
# Saint Helena        SUCCESS
# Saint Helena        SUCCESS
# Saint Helena        SUCCESS
# Saint Helena        SUCCESS
# Saint Helena        SUCCESS
#                      ...
# Christmas Island     FAILED
# Christmas Island     FAILED
# Christmas Island     FAILED
# Christmas Island     FAILED
# Christmas Island     FAILED
# Name: status, Length: 578320, dtype: object

# %%
def lower_case(x):
    return x.lower()

# %%
df2["status"].apply(lower_case)
# Out:
# location
# Saint Helena        success
# Saint Helena        success
# Saint Helena        success
# Saint Helena        success
# Saint Helena        success
#                      ...
# Christmas Island     failed
# Christmas Island     failed
# Christmas Island     failed
# Christmas Island     failed
# Christmas Island     failed
# Name: status, Length: 578320, dtype: object

# %%
df2.columns
# Out:
# Index(['customer_ID', 'DEVICE_ID', 'item_id', 'line_item_id', 'order_id',
#        'event_id', 'event_timestamp', 'quantity', 'currency', 'checked_out_at',
#        'status'],
#       dtype='object')

# %%
df2_copy= df2[["currency", "status"]]

# %%
df2_copy
# Out:
#                  currency   status
# location
# Saint Helena          NGN  success
# Saint Helena          NGN  success
# Saint Helena          NGN  success
# Saint Helena          NGN  success
# Saint Helena          NGN  success
# ...                   ...      ...
# Christmas Island      USD   failed
# Christmas Island      USD   failed
# Christmas Island      USD   failed
# Christmas Island      USD   failed
# Christmas Island      USD   failed
#
# [578320 rows x 2 columns]

# %%
df2_copy["currency"]
# Out:
# location
# Saint Helena        NGN
# Saint Helena        NGN
# Saint Helena        NGN
# Saint Helena        NGN
# Saint Helena        NGN
#                    ...
# Christmas Island    USD
# Christmas Island    USD
# Christmas Island    USD
# Christmas Island    USD
# Christmas Island    USD
# Name: currency, Length: 578320, dtype: object

# %%
df2_copy["currency"]= df2_copy["currency"].map({"USD":"EUR"})
# Out:
# C:\Users\Adenuga Pelumi\AppData\Local\Temp\ipykernel_1324\687082833.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_copy["currency"]= df2_copy["currency"].map({"USD":"EUR"})

# %%
new_copy3 = df2.copy()[-15:-1]

# %%
new_copy3.head(3)
# Out:
# location
# Christmas Island    failed
# Christmas Island    failed
# Christmas Island    failed
# Name: status, dtype: object

# %%
import numpy as np

# %%
looping= df2[["quantity", "currency", "status"]].reset_index()
looping
# Out:
#                 location  quantity currency   status
# 0           Saint Helena         2      NGN  success
# 1           Saint Helena         4      NGN  success
# 2           Saint Helena         5      NGN  success
# 3           Saint Helena         1      NGN  success
# 4           Saint Helena         2      NGN  success
# ...                  ...       ...      ...      ...
# 578315  Christmas Island         3      USD   failed
# 578316  Christmas Island         3      USD   failed
# 578317  Christmas Island         3      USD   failed
# 578318  Christmas Island         3      USD   failed
# 578319  Christmas Island         3      USD   failed
#
# [578320 rows x 4 columns]

# %%
looping["status"].str.strip()
# Out:
# 0         success
# 1         success
# 2         success
# 3         success
# 4         success
#            ...
# 578315     failed
# 578316     failed
# 578317     failed
# 578318     failed
# 578319     failed
# Name: status, Length: 578320, dtype: object

# %%
looping.head(2)
# Out:
#        location  quantity currency   status
# 0  Saint Helena         2      NGN  success
# 1  Saint Helena         4      NGN  success

# %%
dic= {'success':'s', 'failed':'f', 'cancelled':'c'}

# %%
def fasterloop(df,search_col_name, applycolumns, dictionaryofvalues,elsevalue=""):
    for i, j in dic.items():
        mask=df[search_col_name]==i
        df.loc[mask, applycolumns]= j
    if elsevalue=="":
        pass
    else:
        df = df[applycolumnname.fillna(elsevalue)]

# %%
fasterloop(looping,"status","payment_stat_abr",dic)

# %%
looping.head()
# Out:
#        location  quantity currency   status payment_stat_abr
# 0  Saint Helena         2      NGN  success                s
# 1  Saint Helena         4      NGN  success                s
# 2  Saint Helena         5      NGN  success                s
# 3  Saint Helena         1      NGN  success                s
# 4  Saint Helena         2      NGN  success                s

# %%
mask15=looping["quantity"] >=4

# %%
looping[mask15].shape[0]
# Out:
# 232163

# %%
looping[mask15].index
# Out:
# Index([     1,      2,      5,      7,      8,     11,     13,     14,     17,
#            19,
#        ...
#        578250, 578255, 578260, 578265, 578270, 578275, 578280, 578285, 578290,
#        578295],
#       dtype='int64', length=232163)

# %%
most_quants = looping.drop(index = looping[~mask15].index)

# %%
most_quants
# Out:
#              location  quantity currency     status
# 1        Saint Helena         4      NGN    success
# 2        Saint Helena         5      NGN    success
# 5        Saint Helena         4      NGN    success
# 7        Saint Helena         4      NGN    success
# 8        Saint Helena         5      NGN    success
# ...               ...       ...      ...        ...
# 578275  Liechtenstein         4      GBP  cancelled
# 578280  Liechtenstein         4      GBP  cancelled
# 578285  Liechtenstein         4      GBP  cancelled
# 578290  Liechtenstein         4      GBP  cancelled
# 578295  Liechtenstein         4      GBP  cancelled
#
# [232163 rows x 4 columns]

# %%
make_index=looping.copy()

# %%
make_index.set_index("location", inplace=True)

# %%
make_index.head(3)
# Out:
#               quantity currency   status
# location
# Saint Helena         2      NGN  success
# Saint Helena         4      NGN  success
# Saint Helena         5      NGN  success

# %%
make_index.drop(index = "Saint Helena", inplace = True)

# %%
make_index.head(3)
# Out:
#           quantity currency  status
# location
# Djibouti         3      NGN  failed
# Djibouti         3      NGN  failed
# Djibouti         3      NGN  failed

# %%
group_df= make_index

# %%
grouped= group_df.groupby(["status"])

# %%
grouped["quantity"].count()
# Out:
# status
# cancelled    188287
# failed       195438
# success      191750
# Name: quantity, dtype: int64
